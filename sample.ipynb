# %%
import matplotlib.pyplot as plt

# %%
import modeltools

# %%
# 分布のみを確認する際は正規化する。
# １回でも測定された値を確認するなら無効にする
modeltools.Histogram.normalize(True)
# レイテンシのサイズを調整
modeltools.Histogram.trim(False)

# %%
app = modeltools.read_json('sample_data/architecture.json')

# %%
app.latencies
# Out:
# [<modeltools.latency.Latency at 0x7fd53789f668>,
#  <modeltools.latency.Latency at 0x7fd53783e400>,
#  <modeltools.latency.Latency at 0x7fd53783e6d8>]

# %%
plt.plot(app.latencies[0].hist.raw)

# %%
app.latencies[0].child
# Out:
# [<modeltools.node.Node at 0x7fd53579afd0>,
#  <modeltools.application.Communication at 0x7fd5378a8828>,
#  <modeltools.node.Node at 0x7fd5357db1d0>,
#  <modeltools.application.Communication at 0x7fd5378a8c18>,
#  <modeltools.node.Node at 0x7fd537883240>,
#  <modeltools.application.Communication at 0x7fd5378b5390>,
#  <modeltools.node.Node at 0x7fd535784fd0>,
#  <modeltools.application.Communication at 0x7fd5378b5d30>,
#  <modeltools.node.Node at 0x7fd5357db2b0>]

# %%
node = app.latencies[0].child[6]
print(node.name)
plt.plot(node.latency.hist.raw)
# Out:
# /timer_dependency_node

# %%
node.latency.child
# Out:
# [<modeltools.callback.SubscribeCallback at 0x7fd5378b5080>,
#  <modeltools.node.Execution at 0x7fd5378b5400>,
#  <modeltools.callback.TimerCallback at 0x7fd5378b51d0>]

# %%
subscribe_callback = node.latency.child[0]
plt.plot(subscribe_callback.latency.hist.raw)

# %%
plt.plot(subscribe_callback.latency.timeseries.raw)

# %%
app.nodes
# Out:
# [<modeltools.node.Node at 0x7fd53789fbe0>,
#  <modeltools.node.Node at 0x7fd53789fc18>,
#  <modeltools.node.Node at 0x7fd5378a8978>,
#  <modeltools.node.Node at 0x7fd5378a8e80>,
#  <modeltools.node.Node at 0x7fd5378a8fd0>]

# %%
plt.plot(app.communications[0].latency.hist.raw)

# %%
# ノード毎の検証
node = app.nodes[3]
node.callbacks
# Out:
# [<modeltools.callback.SubscribeCallback at 0x7fd5378b5080>,
#  <modeltools.callback.TimerCallback at 0x7fd5378b51d0>]

# %%
node.latencies
# Out:
# [<modeltools.latency.Latency at 0x7fd535608710>,
#  <modeltools.latency.Latency at 0x7fd535608c50>]

# %%
callback = node.callbacks[0]
plt.plot(callback.latency.hist.raw)

# %%
node.executions

# %%
execution = node.executions[0]
plt.plot(execution.latency.hist.raw)
